# %%
# import the pandas library
import pandas as pd

# %%
# input the dataset
# read it somehow
fpath = "../Project 4 Datasets/ncaa-team-data.csv"
# read it into a pandas datastructure
dataset = pd.read_csv(fpath)
dataset
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/xz/_hjc5hsx743dclmg8n5678nc0000gn/T/ipykernel_71602/4240648671.py in <module>
#       3 fpath = "../Project 4 Datasets/ncaa-team-data.csv"
#       4 # read it into a pandas datastructure
# ----> 5 dataset = pd.read_csv(fpath)
#       6 dataset
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     480
#     481     # Create the parser.
# --> 482     parser = TextFileReader(filepath_or_buffer, **kwds)
#     483
#     484     if chunksize or iterator:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#     809             self.options["has_index_names"] = kwds["has_index_names"]
#     810
# --> 811         self._engine = self._make_engine(self.engine)
#     812
#     813     def close(self):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py in _make_engine(self, engine)
#    1038             )
#    1039         # error: Too many arguments for "ParserBase"
# -> 1040         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1041
#    1042     def _failover_to_python(self):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/c_parser_wrapper.py in __init__(self, src, **kwds)
#      49
#      50         # open handles
# ---> 51         self._open_handles(src, kwds)
#      52         assert self.handles is not None
#      53
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/base_parser.py in _open_handles(self, src, kwds)
#     220         Let the readers open IOHandles after they are done with their potential raises.
#     221         """
# --> 222         self.handles = get_handle(
#     223             src,
#     224             "r",
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     700         if ioargs.encoding and "b" not in ioargs.mode:
#     701             # Encoding
# --> 702             handle = open(
#     703                 handle,
#     704                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: '../Project 4 Datasets/ncaa-team-data.csv'

# %%
# analyze ncaa-team-data to figure out the top 5 teams in terms of all-time NCAA final wins

# compute the number of wins per team
# go through the dataset, grouped by team
grouped_dataset = []
for team, teamData in dataset.groupby("school"):
    numwins = 0
    # go through teh results of that team
    for result in teamData['ncaa_result']:
        # if it won
        if result == "Won National Final":
            # add to our count
            numwins += 1
    teamResults = {
        'team': team,
        'numWins': numwins
    }
    # add the results to the results dataset
    grouped_dataset.append(teamResults)
# turn the results dataset into a dataframe
print(grouped_dataset)
grouped_dataset = pd.DataFrame(grouped_dataset)
grouped_dataset

# sort the dataset by number of wins, descending
grouped_dataset = grouped_dataset.sort_values(by="numWins", ascending=False)
# show the top 5
top5 = grouped_dataset.head(10)
top5
# Out:
# [{'team': 'air-force', 'numWins': 0}, {'team': 'akron', 'numWins': 0}, {'team': 'alabama', 'numWins': 0}, {'team': 'alabama-birmingham', 'numWins': 0}, {'team': 'alabama-state', 'numWins': 0}, {'team': 'alcorn-state', 'numWins': 0}, {'team': 'allegheny', 'numWins': 0}, {'team': 'american', 'numWins': 0}, {'team': 'appalachian-state', 'numWins': 0}, {'team': 'arizona', 'numWins': 1}, {'team': 'arizona-state', 'numWins': 0}, {'team': 'arkansas', 'numWins': 1}, {'team': 'arkansas-little-rock', 'numWins': 0}, {'team': 'arkansas-state', 'numWins': 0}, {'team': 'army', 'numWins': 0}, {'team': 'auburn', 'numWins': 0}, {'team': 'austin-peay', 'numWins': 0}, {'team': 'ball-state', 'numWins': 0}, {'team': 'baylor', 'numWins': 0}, {'team': 'bethune-cookman', 'numWins': 0}, {'team': 'boise-state', 'numWins': 0}, {'team': 'boston-college', 'numWins': 0}, {'team': 'boston-university', 'numWins': 0}, {'team': 'bowling-green-state', 'numWins': 0}, {'team': 'bradley', 'numWins': 0}, {'team': 'brigham-young', 'numWins': 0}, {'team': 'brooklyn', 'numWins': 0}, {'team': 'brown', 'numWins': 0}, {'team': 'bucknell', 'numWins': 0}, {'team': 'buffalo', 'numWins': 0}, {'team': 'butler', 'numWins': 0}, {'team': 'cal-poly', 'numWins': 0}, {'team': 'cal-state-fullerton', 'numWins': 0}, {'team': 'cal-state-northridge', 'numWins': 0}, {'team': 'california', 'numWins': 1}, {'team': 'california-irvine', 'numWins': 0}, {'team': 'california-santa-barbara', 'numWins': 0}, {'team': 'campbell', 'numWins': 0}, {'team': 'canisius', 'numWins': 0}, {'team': 'carleton-college', 'numWins': 0}, {'team': 'centenary-la', 'numWins': 0}, {'team': 'central-connecticut-state', 'numWins': 0}, {'team': 'central-florida', 'numWins': 0}, {'team': 'central-michigan', 'numWins': 0}, {'team': 'charleston-southern', 'numWins': 0}, {'team': 'charlotte', 'numWins': 0}, {'team': 'chattanooga', 'numWins': 0}, {'team': 'chicago', 'numWins': 0}, {'team': 'chicago-state', 'numWins': 0}, {'team': 'cincinnati', 'numWins': 2}, {'team': 'citadel', 'numWins': 0}, {'team': 'city-college-of-new-york', 'numWins': 1}, {'team': 'clemson', 'numWins': 0}, {'team': 'cleveland-state', 'numWins': 0}, {'team': 'coastal-carolina', 'numWins': 0}, {'team': 'colgate', 'numWins': 0}, {'team': 'college-of-charleston', 'numWins': 0}, {'team': 'colorado', 'numWins': 0}, {'team': 'colorado-college', 'numWins': 0}, {'team': 'colorado-school-of-mines', 'numWins': 0}, {'team': 'colorado-state', 'numWins': 0}, {'team': 'columbia', 'numWins': 0}, {'team': 'connecticut', 'numWins': 4}, {'team': 'coppin-state', 'numWins': 0}, {'team': 'cornell', 'numWins': 0}, {'team': 'creighton', 'numWins': 0}, {'team': 'dartmouth', 'numWins': 0}, {'team': 'davidson', 'numWins': 0}, {'team': 'dayton', 'numWins': 0}, {'team': 'delaware', 'numWins': 0}, {'team': 'delaware-state', 'numWins': 0}, {'team': 'denison', 'numWins': 0}, {'team': 'denver', 'numWins': 0}, {'team': 'depaul', 'numWins': 0}, {'team': 'detroit-mercy', 'numWins': 0}, {'team': 'drake', 'numWins': 0}, {'team': 'drexel', 'numWins': 0}, {'team': 'duke', 'numWins': 5}, {'team': 'duquesne', 'numWins': 0}, {'team': 'east-carolina', 'numWins': 0}, {'team': 'east-tennessee-state', 'numWins': 0}, {'team': 'eastern-illinois', 'numWins': 0}, {'team': 'eastern-kentucky', 'numWins': 0}, {'team': 'eastern-michigan', 'numWins': 0}, {'team': 'eastern-washington', 'numWins': 0}, {'team': 'evansville', 'numWins': 0}, {'team': 'fairfield', 'numWins': 0}, {'team': 'fairleigh-dickinson', 'numWins': 0}, {'team': 'florida', 'numWins': 2}, {'team': 'florida-am', 'numWins': 0}, {'team': 'florida-atlantic', 'numWins': 0}, {'team': 'florida-international', 'numWins': 0}, {'team': 'florida-state', 'numWins': 0}, {'team': 'fordham', 'numWins': 0}, {'team': 'fresno-state', 'numWins': 0}, {'team': 'furman', 'numWins': 0}, {'team': 'george-mason', 'numWins': 0}, {'team': 'george-washington', 'numWins': 0}, {'team': 'georgetown', 'numWins': 1}, {'team': 'georgia', 'numWins': 0}, {'team': 'georgia-southe ...
#                team  numWins
# 299            ucla       11
# 136        kentucky        8
# 124         indiana        5
# 77             duke        5
# 198  north-carolina        5
# 62      connecticut        4
# 133          kansas        3
# 148      louisville        3
# 49       cincinnati        2
# 88          florida        2

# %%
# show me all the times that ucla won
dataset[(dataset['ncaa_result']=="Won National Final") & (dataset['school'] == "ucla")].sort_values(by="year", ascending=False)
# Out:
#       school    conf  rk     w    l     wl    srs    sos  pts_for  pts_vs  \
# 20960   ucla  Pac-10  23  31.0  2.0  0.939  23.74  10.08     87.5     NaN
# 20980   ucla   Pac-8  43  28.0  3.0  0.903  21.07   8.55      NaN     NaN
# 20982   ucla   Pac-8  45  30.0  0.0  1.000  27.98   6.71      NaN     NaN
# 20983   ucla   Pac-8  46  30.0  0.0  1.000  33.79   3.46      NaN     NaN
# 20984   ucla   Pac-8  47  29.0  1.0  0.967  20.91   5.98      NaN     NaN
# 20985   ucla   Pac-8  48  28.0  2.0  0.933  25.02   6.42      NaN     NaN
# 20986   ucla   Pac-8  49  29.0  1.0  0.967  26.69   5.85      NaN     NaN
# 20987   ucla    AAWU  50  29.0  1.0  0.967  32.56   6.33      NaN     NaN
# 20988   ucla    AAWU  51  30.0  0.0  1.000  29.39   3.49      NaN     NaN
# 20990   ucla    AAWU  53  28.0  2.0  0.933  21.33   7.09      NaN     NaN
# 20991   ucla    AAWU  54  30.0  0.0  1.000  22.51   4.35      NaN     NaN
#
#        pts_total  ap_pre  ap_high  ap_final  pts_diff         ncaa_result  \
# 20960        NaN     6.0      1.0       1.0       NaN  Won National Final
# 20980        NaN     2.0      1.0       1.0       NaN  Won National Final
# 20982        NaN     1.0      1.0       1.0       NaN  Won National Final
# 20983        NaN     1.0      1.0       1.0       NaN  Won National Final
# 20984        NaN     1.0      1.0       1.0       NaN  Won National Final
# 20985        NaN     4.0      1.0       2.0       NaN  Won National Final
# 20986        NaN     1.0      1.0       1.0       NaN  Won National Final
# 20987        NaN     1.0      1.0       2.0       NaN  Won National Final
# 20988        NaN     1.0      1.0       1.0       NaN  Won National Final
# 20990        NaN     2.0      1.0       2.0       NaN  Won National Final
# 20991        NaN    30.0      1.0       1.0       NaN  Won National Final
#
#        ncaa_numeric   season             coaches    year
# 20960          48.0  1994-95  Jim Harrick (31-2)  1994.0
# 20980          48.0  1974-75  John Wooden (28-3)  1974.0
# 20982          48.0  1972-73  John Wooden (30-0)  1972.0
# 20983          48.0  1971-72  John Wooden (30-0)  1971.0
# 20984          48.0  1970-71  John Wooden (29-1)  1970.0
# 20985          48.0  1969-70  John Wooden (28-2)  1969.0
# 20986          48.0  1968-69  John Wooden (29-1)  1968.0
# 20987          48.0  1967-68  John Wooden (29-1)  1967.0
# 20988          48.0  1966-67  John Wooden (30-0)  1966.0
# 20990          48.0  1964-65  John Wooden (28-2)  1964.0
# 20991          48.0  1963-64  John Wooden (30-0)  1963.0

# %%
grouped_dataset2 = []
for group, groupData in dataset.groupby("conf"):
    numwins = 0
    # go through teh results of that team
    for result in groupData['ncaa_result']:
        # if it won
        if result == "Won National Final":
            # add to our count
            numwins += 1
    groupResults = {
        'conf': group,
        'numWins': numwins
    }
    # add the results to the results dataset
    grouped_dataset2.append(groupResults)
# turn the results dataset into a dataframe
grouped_dataset2 = pd.DataFrame(grouped_dataset2)
grouped_dataset2.sort_values(by="numWins", ascending=False)
# Out:
#         conf  numWins
# 4        ACC       13
# 60       SEC       11
# 16   Big Ten       10
# 13  Big East        8
# 58     Pac-8        6
# ..       ...      ...
# 35       MAC        0
# 1      A-Sun        0
# 37       MCC        0
# 38      MEAC        0
# 72    Yankee        0
#
# [73 rows x 2 columns]
