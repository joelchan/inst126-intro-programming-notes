# %% [markdown]
# ## Practice 1
#
# A gym offers a discount if you are either a student or over 65 years old. Write a function that takes the student status and age as input parameters, and returns True or False for discount status.

# %%
# some test inputs
isStudent = False
age = 66

# put this expression into the body of the function in the next cell
isStudent == True or age > 65

# %%
# define your function here
# remember to change your function name
# and put appropriate parameters in the definition
def nameYourFunction():
    return

# %%
studentStatus = True
customerAge = 35

# call your function here on the next line with studentStatus and customerAge as arguments for your function's parameters

# %%
is_a_student = True
age_of_customer = 45

# call your function here on the next line with is_a_student and age_of_customer as arguments for your function's parameters

# %% [markdown]
# ## Practice 2
#
# A recipe calls for 0.167 cups of flour for each cookie you want to make. Write a function that returns the number of cups of flour you need for a target number of cookies.

# %%
# some test inputs
num_cookies = 15

# put this expression into the body of the function in the next cell
num_cookies*0.167

# %%
# define your function here
# remember to change your function name
# and put appropriate parameter(s) in the definition
def nameYourFunction():
    return

# %%
target_num_cookies = 45

# call your function here on the next line with target_num_cookies as argument for your function's parameter

# %%
desired_cookies = 8

# call your function here on the next line with desired_cookies as argument for your function's parameter

# %% [markdown]
# ## Practice 3
#
# Write a function that calculates the final score for an assignment, taking into account any potential deductions for lateness, per our syllabus late policy (0.25% deduction per hour late)

# %%
# some test inputs
hours_late = 3
score = 30
maximum_score = 50

# put this expression into the body of the function in the next cell
percent_deduction = hours_late*0.25
points_deduction = percent_deduction/100*maximum_score
score - points_deduction

# %%
# define your function here
# remember to change your function name
# and put appropriate parameter(s) in the definition
def nameYourFunction():
    return

# %%
num_hours_late = 24*10
initial_score = 55
possible_score = 60

# call your function here on the next line with num_hours_late, initial_score, and possible_score as arguments for your function's parameters

# %%
late_hours_amount = 36
points_earned = 15
points_possible = 20

# call your function here on the next line with late_hours_amount, points_earned, and points_possible as arguments for your function's parameters
