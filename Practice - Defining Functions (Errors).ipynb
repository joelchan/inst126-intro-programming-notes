# %% [markdown]
# ## Practice 1
#
# A gym offers a discount if you are either a student or over 65 years old. Debug a function that takes the student status and age as input parameters, and returns True or False for discount status.

# %%
def discount_eligibility(isStudent, age):
    isStudent = False
    age = 35
    result = isStudent == True or age > 65
    return result

# %%
studentStatus = True
customerAge = 35

discount_eligibility(isStudent=studentStatus, age=customerAge)
# Out:
# False

# %% [markdown]
# ## Practice 2
#
# A recipe calls for 0.167 cups of flour for each cookie you want to make. Debug a function that returns the number of cups of flour you need for a target number of cookies.

# %%
def cups_per_cookie(num_cookies):
    result = num_cookies*0.167
    print(result)

# %%
target_num_cookies = 12

num_cups = cups_per_cookie(num_cookies=target_num_cookies)
print("We need", num_cups, "of flour to make", target_num_cookies, "cookies")
# Out:
# 2.004
# We need None of flour to make 12 cookies

# %% [markdown]
# ## Practice 3
#
# Debug a program that calls a function to calculate the final score for an assignment, taking into account any potential deductions for lateness, per our syllabus late policy (0.25% deduction per hour late)

# %%
def final_score(hours_late, score, maximum_score):
    percent_deduction = hours_late*0.25
    points_deduction = percent_deduction/100*maximum_score
    result = score - points_deduction
    return score

# %%
num_hours_late = 2
initial_score = 55
possible_score = 60

final_score(num_hours_late, initial_score, possible_score)
# Out:
# 55

# %% [markdown]
# ## Practice 4
#
# A movie theater offers a group discount if a party has 5 or more people or if at least one member of the group is a loyalty cardholder. Debug a function that determines whether a group is eligible for a discount.

# %%
def group_discount(group_size, has_loyalty_card):
    group_size = 3
    has_loyalty_card = False
    result = group_size >= 5 or has_loyalty_card == True
    return result

# %%
num_in_group = 6
loyalty_card = False
discount = group_discount(num_in_group, loyalty_card)
print("Discount eligibility for this group:", discount)
# Out:
# Discount eligibility for this group: False

# %% [markdown]
# ## Practice 5
#
# A fitness tracker records the number of steps taken each day. If the total steps for a day exceed 10,000, the user earns a "goal achieved" badge. Debug a function that determines whether the badge is earned.

# %%
def goal_achieved(steps):
    result = steps_today >= 10000
    return result

# %%
badge = goal_achieved(12000)
print(badge)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 badge = goal_achieved(12000)
#       2 print(badge)
#
# Cell In[12], line 2, in goal_achieved(steps)
#       1 def goal_achieved(steps):
# ----> 2     result = steps_today >= 10000
#       3     return result
#
# NameError: name 'steps_today' is not defined

# %% [markdown]
# ## Practice 6
#
# A theme park allows kids to ride if they have a fast pass or are at least 48 inches tall. Debug the following program that tests whether a kid can ride according to these rules.

# %%
def ride_eligibility(fast_pass, height):
    eligible = fast_pass or height >= 48
    return eligible

# %%
# Test case
can_ride = ride_eligible(fast_pass=False, height=50)
print("This person can ride:", can_ride)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 2
#       1 # Test case
# ----> 2 can_ride = ride_eligible(fast_pass=False, height=50)
#       3 print("This person can ride:", can_ride)
#
# NameError: name 'ride_eligible' is not defined

# %% [markdown]
# ## Practice 7
#
# Debug the following program that calculates a final amount to pay, taking tip into account

# %%
def tip(base_price, tip_prop):
    result = base_price*tip_prop
    print(result)

check = 50
tip_proportion = .18

total = check + tip(base_price=check, tip_prop=tip_proportion)
print("Total amount is", total)
# Out:
# 9.0
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 8
#       5 check = 50
#       6 tip_proportion = .18
# ----> 8 total = check + tip(base_price=check, tip_prop=tip_proportion)
#       9 print("Total amount is", total)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'NoneType'
